# %% [raw]
# ---
# description: Handle interaction with AWSTranscribe, in order to retreive json data
#   of audio file
# output-file: awstranscribe.html
# title: AWSTranscribe
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(AWSTranscribe)
# Out:
# ---
#
# ### AWSTranscribe
#
# >      AWSTranscribe (input_bucket, output_bucket)
#
# *A class that will upload audio files to s3 and then execute transcription jobs for them using AWSTranscribe*

# %%
#| echo: false
#| output: asis
show_doc(start_job)
# Out:
# ---
#
# ### start_job
#
# >      start_job (job_name, media_uri, media_format, language_code,
# >                 transcribe_client, vocabulary_name=None)
#
# *Starts a transcription job. This function returns as soon as the job is started.
# To get the current status of the job, call get_transcription_job. The job is
# successfully completed when the job status is 'COMPLETED'.
#
# :param job_name: The name of the transcription job. This must be unique for
#                  your AWS account.
# :param media_uri: The URI where the audio file is stored. This is typically
#                   in an Amazon S3 bucket.
# :param media_format: The format of the audio file. For example, mp3 or wav.
# :param language_code: The language code of the audio file.
#                       For example, en-US or ja-JP
# :param transcribe_client: The Boto3 Transcribe client.
# :param vocabulary_name: The name of a custom vocabulary to use when transcribing
#                         the audio file.
# ...

# %%
file_name = 'data/2023_02_27_11_49_35_CH12_MIX.mp3'
awstrans = AWSTranscribe('weinberg-transcriptions','weinberg-transcript-ouput')
#awstrans.uploadFile(file_name)
#awstrans.printInputBucketContents()
# Out:
# CASE003/ 2024-08-28 12:50:20+00:00
# CASE003/2023_02_27_09_25_15_CH12_MIX.mp3 2024-08-28 12:50:36+00:00
# CASE003/2023_02_27_11_49_35_CH12_MIX.mp3 2024-08-28 12:50:36+00:00
# ZOOM0008.mp3 2024-01-04 21:13:26+00:00
# ZOOM0009.mp3 2024-01-25 20:57:52+00:00
# output.txt 2024-09-07 06:25:32+00:00
# test_01_video_interview.wav 2023-11-18 06:30:18+00:00

# %%
awstrans.createTranscriptionJob(file_name)
# Out:
# File extension: mp3
# File MIME type: audio/mpeg
